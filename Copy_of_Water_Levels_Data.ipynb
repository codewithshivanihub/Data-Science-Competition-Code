# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithshivanihub/Data-Science-Competition-Code/blob/main/Copy_of_Water_Levels_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-282d6eae-2450-4f0e-bb2e-4a95e768b138" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-282d6eae-2450-4f0e-bb2e-4a95e768b138">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
#    Unnamed: 0            Timestamp  Stage (ft)  Flow (cfs)
# 0       0.131                  NaN         NaN         NaN
# 1         NaN  2022-10-01T01:00:00       0.131        0.25
# 2         NaN  2022-10-01T01:45:00       0.131        0.25
# 3         NaN  2022-10-01T02:00:00       0.131        0.25
# 4         NaN  2022-10-01T02:15:00       0.131        0.25

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df = df.sort_values('Timestamp')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df['Timestamp'], df['Stage (ft)'], color='blue')
plt.title('Water Level (Stage) Over Time - Alamo Creek')
plt.xlabel('Date')
plt.ylabel('Stage (ft)')
plt.grid(True)
plt.show()

# %%
df['Year'] = df['Timestamp'].dt.year
yearly_avg = df.groupby('Year')['Stage (ft)'].mean()
yearly_avg
# Out:
# Year
# 2022.0    0.315104
# 2023.0    0.391186
# 2024.0    0.385331
# 2025.0    0.264816
# 2026.0    0.367779
# Name: Stage (ft), dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.plot(yearly_avg.index, yearly_avg.values, marker='o')
plt.title('Average Water Level by Year')
plt.xlabel('Year')
plt.ylabel('Average Stage (ft)')
plt.grid(True)
plt.show()
